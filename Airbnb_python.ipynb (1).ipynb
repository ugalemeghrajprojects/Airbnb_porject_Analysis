# %%
# Importing libraries.

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load dataset and see first 5 value.

data = pd.read_csv("compressed_data.csv")
data.head()
# Out:
# C:\Users\meghraj\AppData\Local\Temp\ipykernel_21544\3915600774.py:3: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("compressed_data.csv")
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %% [markdown]
# # Chacking missing value

# %%
print(data.isnull().sum())
# Out:
# id                                     0
# NAME                                 250
# host id                                0
# host_identity_verified               289
# host name                            406
# neighbourhood group                   29
# neighbourhood                         16
# lat                                    8
# long                                   8
# country                              532
# country code                         131
# instant_bookable                     105
# cancellation_policy                   76
# room type                              0
# Construction year                    214
# price                                247
# service fee                          273
# minimum nights                       409
# number of reviews                    183
# last review                        15893
# reviews per month                  15879
# review rate number                   326
# calculated host listings count       319
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %% [markdown]
# # Change a dtype

# %%
data['last review'] = pd.to_datetime(data['last review'], errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %%
# felling nan value as 0 and min of last review.

data.fillna(
        {'reviews per month' : 0,
         'last review' : data['last review'].min()},
        inplace= True)

# %%
# Droping missing value from name and host name column. 

data.dropna(subset=['NAME','host name'],inplace = True)

# %%
print(data.isnull().sum())
# Out:
# id                                     0
# NAME                                   0
# host id                                0
# host_identity_verified               276
# host name                              0
# neighbourhood group                   26
# neighbourhood                         16
# lat                                    8
# long                                   8
# country                              526
# country code                         122
# instant_bookable                      96
# cancellation_policy                   70
# room type                              0
# Construction year                    200
# price                                239
# service fee                          268
# minimum nights                       403
# number of reviews                    182
# last review                            0
# reviews per month                      0
# review rate number                   314
# calculated host listings count       318
# ...

# %%
# Droping null columns.

data= data.drop(columns=["license","house_rules"],errors='ignore')

# %%
data.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5  1004098         Large Cozy 1 BR Apartment In Midtown East  45498551794
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 4               verified    Lyndon           Manhattan   East Harlem
# 5               verified  Michelle           Manhattan   Murray Hill
#
#         lat      long        country  ... Construction year  price  \
# ...

# %%
# removing $ sine for price and service fee column.

data['price']= data['price'].replace('[\$,]','',regex=True).astype(float)
data['service fee'] = data['service fee'].replace('["\$"]','',regex=True).astype(float)

# %%
data.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5  1004098         Large Cozy 1 BR Apartment In Midtown East  45498551794
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 4               verified    Lyndon           Manhattan   East Harlem
# 5               verified  Michelle           Manhattan   Murray Hill
#
#         lat      long        country  ... Construction year  price  \
# ...

# %% [markdown]
# # Remove Duplicates

# %%
data.drop_duplicates(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101410 entries, 0 to 102057
# Data columns (total 24 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              101410 non-null  int64
#  1   NAME                            101410 non-null  object
#  2   host id                         101410 non-null  int64
#  3   host_identity_verified          101134 non-null  object
#  4   host name                       101410 non-null  object
#  5   neighbourhood group             101384 non-null  object
#  6   neighbourhood                   101394 non-null  object
#  7   lat                             101402 non-null  float64
#  8   long                            101402 non-null  float64
#  9   country                         100884 non-null  object
#  10  country code                    101288 non-null  object
#  11  instant_bookable                101314 non-null  object
# ...

# %%
print(data['price'].describe())
# Out:
# count    101171.000000
# mean        625.381008
# std         331.609111
# min          50.000000
# 25%         340.000000
# 50%         625.000000
# 75%         913.000000
# max        1200.000000
# Name: price, dtype: float64

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # 01 What is the distribution of listing prices?

# %%
# creating graph according price.

plt.figure(figsize=(8,5))
sns.histplot(data['price'], bins = 15, kde= True , color= 'black')
plt.title("Distribution of listing Price")
plt.xlabel("Price $")
plt.ylabel("Frequency")
plt.show()

# %% [raw]
# "From this graph, it can be observed that listing prices are spread across different price ranges. No particular price range appears to be the most popular or dominant. Therefore, the distribution of prices in the dataset is relatively balanced, and the listings are not concentrated around a specific price point."

# %%
data.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5  1004098         Large Cozy 1 BR Apartment In Midtown East  45498551794
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 4               verified    Lyndon           Manhattan   East Harlem
# 5               verified  Michelle           Manhattan   Murray Hill
#
#         lat      long        country  ... Construction year  price  \
# ...

# %%
data['room type'].head(10)
# Out:
# 0        Private room
# 1     Entire home/apt
# 2        Private room
# 4     Entire home/apt
# 5     Entire home/apt
# 6        Private room
# 7        Private room
# 8        Private room
# 9        Private room
# 10    Entire home/apt
# Name: room type, dtype: object

# %% [markdown]
# # 02 How are different room types distributed?

# %%
# show chart total types of room and conunt of rooms.

plt.figure(figsize=(6,4))
sns.countplot(x ='room type', data = data, color = "hotpink")
plt.title("Rooms type Distribution")
plt.xlabel("Types of Rooms")
plt.ylabel("Counts of Rooms")
plt.show()

# %% [raw]
# The dataset is dominated by Entire home/apartment listings, followed by Private rooms. Shared rooms and Hotel rooms represent only a small fraction of the total listings. This indicates that guests generally prefer renting entire properties or private rooms rather than shared accommodations.

# %% [markdown]
# # 03 How are listings distributed across different neighborhoods?

# %%
# finding neighborhoods and listing diff.

plt.figure(figsize=(7,4))
sns.countplot(y="neighbourhood group",data= data , color="lightgreen", order=data['neighbourhood group'].value_counts().index)
plt.title('Number of Listings by Neighborhood Group')
plt.ylabel('Neighorhood Group')
plt.xlabel('count')
plt.show('Number of Listings by Neighborhood Group')

# %% [raw]
# The majority of Airbnb listings are concentrated in Manhattan and Brooklyn, making them the dominant neighborhoods in the dataset. Queens has a moderate presence, while the Bronx and Staten Island have relatively few listings. The graph also reveals data quality issues, such as misspelled neighborhood names ("brookln" and "manhatan"), which should be corrected to ensure accurate analysis.

# %% [markdown]
# # 04 What is the relationship between price and room type.

# %%
# finding relationshion between price and room type using box plot.

plt.figure(figsize=(9,5))
sns.boxplot(x='room type',y= 'price', data= data ,palette='Set1')
plt.title('Price vs Room type')
plt.xlabel('Room Type')
plt.ylabel('price ($)')
plt.show('Price vs Room type')
# Out:
# C:\Users\meghraj\AppData\Local\Temp\ipykernel_21544\2002647905.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='room type',y= 'price', data= data ,palette='Set1')

# %%
"An analysis of 'Price vs Room type' via box plot visualization reveals that Room Type is not a significant predictor of price in this dataset. The median price remains tightly clustered around $620–$650 across all categories (Private room, Entire home/apt, Shared room, and Hotel room). Furthermore, the minimum (~$50) and maximum (~$1200) values are uniform across the board. 

While 'Hotel rooms' demonstrate a slightly higher 25th percentile (~$420) compared to the other three categories (~$320–$350), the overall distribution variance is negligible. Because we would statistically expect 'Shared rooms' to skew significantly cheaper than 'Entire homes' or 'Hotel rooms,' it is recommended to audit the data pipeline for potential mixing or formatting errors before using 'Room Type' as a feature in downstream predictive modeling."%%!

# %% [markdown]
# # 05 How  the number of reviews change over with time.

# %%
# to find a reviews are change in time or not.

data['last review'] = pd.to_datetime(data['last review'])
reviews_over_time = data.groupby(data['last review'].dt.to_period('M')).size()

plt.figure(figsize=(12,6))
reviews_over_time.plot(kind='line',color='red')
plt.title('Number fo Reviews Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Reviews')
plt.show('Number fo Reviews Over Time')

# %% [raw]
# 01. The number of reviews increased significantly between 2018 and 2020.
# This suggests that Airbnb experienced strong growth and higher customer activity during this period.
# 02. The highest peak occurs around 2019 (approximately 21,000 reviews).
# This indicates that 2019 was the most active period in the dataset in terms of customer reviews.
# 03. There are several sharp spikes between 2020 and 2022.
# These spikes may represent seasonal demand, special events, or irregularities in the data.
# 04. After 2023, the number of reviews drops close to zero.
# This is unusual and may indicate a data quality issue, missing records, or incorrectly parsed dates.
